# %% [raw]
# ---
# description: "\u30C7\u30FC\u30BF\u30B5\u30A4\u30A8\u30F3\u30B9\u306B\u95A2\u3059\u308B\
#   \u6700\u65B0\u60C5\u5831"
# output-file: index.html
# title: "\u30C7\u30FC\u30BF\u30B5\u30A4\u30A8\u30F3\u30B9\u7DF4\u7FD2\u554F\u984C\u96C6\
#   \ II"
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# このページは、データサイエンス練習問題集 https://scmopt.github.io/analytics の続編であり、主に深層学習と最適化についての最新の話題を紹介する。
